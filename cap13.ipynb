# %%
import xml.etree.ElementTree as ET
datos = '''
<persona>
    <nombre>Chuck</nombre>
    <telefono tipo="intl">
        +1 734 303 4456
    </telefono>
    <email oculto="si"/>
</persona>'''

arbol = ET.fromstring(datos)
print ('Nombre:',arbol.find('nombre').text)
print ('Attr:',arbol.find('telefono').get('tipo'))
print (arbol.find('telefono').text)
# Out:
# Nombre: Chuck
# Attr: intl
#
#         +1 734 303 4456

# %%
import xml.etree.ElementTree as ET
entrada = '''
<cosas>
    <usuarios>
        <usuario x="2">
            <id>001</id>
            <nombre>Chuck</nombre>
        </usuario>
        <usuario x="7">
            <id>009</id>
            <nombre>Brent</nombre>
        </usuario>
    </usuarios>
</cosas>'''
cosas = ET.fromstring(entrada)
lst = cosas.findall('usuarios/usuario')
print ('Cantidad de usuarios:', len(lst))
for elemento in lst:
    print ('Nombre', elemento.find('nombre').text)
    print ('Id', elemento.find('id').text)
    print ('Atributo', elemento.get('x'))
# Out:
# Cantidad de usuarios: 2
# Nombre Chuck
# Id 001
# Atributo 2
# Nombre Brent
# Id 009
# Atributo 7

# %%
import json
entrada = '''
[
    { "id" : "001",
        "x" : "2",
        "nombre" : "Chuck"
    } ,
    { "id" : "009",
        "x" : "7",
        "nombre" : "Brent"
    }
]'''
info = json.loads(entrada)
print ('Cantidad de usuarios:', len(info))
for elemento in info:
    print ('Nombre', elemento['nombre'])
    print ('Id', elemento['id'])
    print ('Atributo', elemento['x'])
# Out:
# Cantidad de usuarios: 2
# Nombre Chuck
# Id 001
# Atributo 2
# Nombre Brent
# Id 009
# Atributo 7

# %%
import urllib
import urllib.request
import json

googleGeocodeUrl = 'https://maps.googleapis.com/maps/api/place/textsearch/json?query='
termino = "Gasolineras"
ubicacion = "&location=@41.7805551,-4.8918108,15&radius=5000"
APIKEY = '&key='+'AIzaSyDwRH947Z0YQZfew5sGcPK-RFd7JtZJKKM'

url = googleGeocodeUrl + termino + ubicacion + APIKEY
print(url)
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=Gasolineras&location=@41.7805551,-4.8918108,15&radius=5000&key=AIzaSyDwRH947Z0YQZfew5sGcPK-RFd7JtZJKKM

# %%
json_response = urllib.request.urlopen(url)
busqueda = json_response.read().decode('utf-8')
busquedajson = json.loads(busqueda)

busquedajson
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CoQC-gAAAI-Y1V1e-SDwsD9hjpuHccnn2MG21Z2ebms13CCoipeSPaheuQEYS4Vu2-7Q8p2x8B673gdlQpULqLhrUdTUeOKiYmyk0ErQgfGPsrUoMHjdsdzoBlCKjpR2n6bn1oWHfwBoPLzOKWp_jt2YK_6jIG2NtdxJxkZbj028-wtF769Btg6_9R-S5pEDot83sMxAq9YU4fx5xff6qG6HRyqhkaeJ9N7gHcJ7lPVXmzmDNSlOuPenp3zbkB8W4cqb2RDlT-3vVLpqJrECUYZcRJ-qcbe5kgS60T466F1fEpBej73ds92m-IieMbmK7HlPe6BmQhIyZm9T81TOK4opXnkJftASEE9M_mR0uRkNk3aoLAhkRr0aFA-lmcLtBbry5hrzjGM4AKvjBp09',
#  'results': [{'formatted_address': 'Av. 33 ##66A-21, Medellín, Antioquia, Colombia',
#    'geometry': {'location': {'lat': 6.2392176, 'lng': -75.58703969999999},
#     'viewport': {'northeast': {'lat': 6.240596779892722,
#       'lng': -75.58569127010728},
#      'southwest': {'lat': 6.237897120107278, 'lng': -75.58839092989271}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#    'id': '05133f60b6d9c17fdb4468bbc090ab6dc0d84aad',
#    'name': 'Esso Bolivariana Autogas',
# ...

# %%
archivolugares = open('ubicaciongasolinera.csv','w')
i=0
for lugar in busquedajson['results']:
    try:
        i = i+1
        print(lugar['name'])
        print(lugar['geometry']['location'])
        archivolugares.write(lugar['name']+','+str(lugar['geometry']['location']['lng'])\
         +','+str(lugar['geometry']['location']['lat'])+'\n')
    except KeyError as e:
        print(e) 
        archivolugares.write(lugar['name']+','+str(lugar['geometry']['location']['lng'])\
         +','+str(lugar['geometry']['location']['lat'])+'\n')
print(i)
archivolugares.close()
# Out:
# Esso Bolivariana Autogas
# {'lat': 6.2392176, 'lng': -75.58703969999999}
# Mobil
# {'lat': 6.245019999999999, 'lng': -75.58901000000002}
# ESSO y GNV EPM
# {'lat': 6.2323039, 'lng': -75.5909305}
# Estacion Terpel La 33
# {'lat': 6.2392467, 'lng': -75.5826507}
# Terpel Belen ( EDS Tanqueadero)
# {'lat': 6.2339839, 'lng': -75.5953909}
# Esso
# {'lat': 6.2460854, 'lng': -75.5925345}
# Texaco Service Station's 70
# {'lat': 6.2494118, 'lng': -75.5888825}
# Terpel - Tenche
# {'lat': 6.232056999999999, 'lng': -75.58264}
# Esso
# {'lat': 6.24918, 'lng': -75.57804}
# Gasolina Extra 8.000
# {'lat': 6.248257799999999, 'lng': -75.58602499999999}
# Terpel
# {'lat': 6.2321785, 'lng': -75.60248700000001}
# Esso - San Juan Lubritodo
# {'lat': 6.2487559, 'lng': -75.5831671}
# Zeuss-Servicentro Porvenir
# {'lat': 6.2284323, 'lng': -75.5776348}
# Terpel - Bridge Nutibara
# {'lat': 6.2379754, 'lng': -75.575789}
# Texaco
# {'lat': 6.24139, 'lng': -75.57128}
# HL COMBUSTIBLES S.A.S
# ...

# %%
import pandas as pd 
columns_names=['Gasolinera:',
              'Longitud',
              'Latitud']
df=pd.read_csv('ubicaciongasolinera.csv',names=columns_names, encoding='latin-1')
df.head()
# Out:
#                        Gasolinera:   Longitud   Latitud
# 0         Esso Bolivariana Autogas -75.587040  6.239218
# 1                            Mobil -75.589010  6.245020
# 2                   ESSO y GNV EPM -75.590930  6.232304
# 3            Estacion Terpel La 33 -75.582651  6.239247
# 4  Terpel Belen ( EDS Tanqueadero) -75.595391  6.233984
